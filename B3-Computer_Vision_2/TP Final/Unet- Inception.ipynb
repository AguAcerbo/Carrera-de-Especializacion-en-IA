# %%
import os
import csv
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
import pickle as pkl
import cv2
import numpy as np
from sklearn import model_selection
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout, BatchNormalization
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.metrics import MeanIoU
import random

# %% [markdown]
# ## Check TF GPU

# %%
if tf.test.gpu_device_name(): 
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device:/device:GPU:0

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %% [markdown]
# ## Load csv and paths

# %%
csv_path = './dataset/train.csv'
train_path = './dataset/train_images/'
train_masks_path = './dataset/train_masks/'

# %%
n_w = 1600
n_h = 256

# %% [markdown]
# ## Create a more balanced dataset with defects and extra 10% without defects

# %%
defective_csv = pd.read_csv(csv_path)
defective_img = [value for value in listdir(train_path) if value in list(defective_csv['ImageId'])]
nondefective_img = [value for value in listdir(train_path) if value not in list(defective_csv['ImageId'])]

# %%
print(len(defective_img))
print(len(nondefective_img))
# Out:
# 6666
# 5902

# %%
idx_aux= np.random.permutation(len(nondefective_img))[0: int(len(defective_img)*0.1)-1]
defective_img = defective_img + [nondefective_img[value] for value in idx_aux]

# %%
len(defective_img)
# Out:
# 7331

# %% [markdown]
# ## Train, Test and Validation

# %%
x_train, x_test = model_selection.train_test_split( defective_img, test_size=0.1, random_state=5)
x_train, x_valid = model_selection.train_test_split( x_train, test_size=0.1, random_state=5)

# %% [markdown]
# ## Functions for inline (RAM) Y defect mask creation

# %%
def decode_pixels(pixels_str):
    """
    This function receives a list which contains the pixels as a space-separated code.
    For example, '1 3 10 5' implies pixels 1,2,3,10,11,12,13,14 are to be included in the mask
    """
    
    pixels_encoded_list = pixels_str.split(' ')
    pixels_list = []
    for i in range(0, len(pixels_encoded_list), 2):
        # Add to the pixels list all the pixels encoded by the 2 digits
        pixels_list += range(
            int(pixels_encoded_list[i]) - 1,
            int(pixels_encoded_list[i]) + int(pixels_encoded_list[i + 1]) - 1,
        )
        
    # Return the decoded list    
    return pixels_list

# %% [raw]
# n_class = 4
# def make_mask_softmax(ImageId):
#
#     y_out=defective_csv[defective_csv['ImageId'].eq(ImageId)]
#
#     image_pixels = np.zeros((n_h, n_w,n_class), dtype=np.float32)
#
#     for index, row in y_out.iterrows():
#
#         # Generate the mask of the error type
#         mask = np.zeros((n_h * n_w, 1), dtype=np.float32)
#         mask[decode_pixels(row['EncodedPixels'])] = 1
#         mask = mask.reshape(n_w, n_h)
#         mask = mask.T
#
#         # Update channel of the given error
#         image_pixels [:,:,int(row['ClassId']-1)] = mask
#
#
#     return image_pixels

# %%
n_class = 1
def make_mask(ImageId):
    
    y_out=defective_csv[defective_csv['ImageId'].eq(ImageId)]
    
    image_pixels = np.zeros((n_h, n_w,n_class), dtype=np.float32)

    for index, row in y_out.iterrows():

        # Generate the mask of the error type
        mask = np.zeros((n_h * n_w, 1), dtype=np.float32)
        mask[decode_pixels(row['EncodedPixels'])] = 1
        mask = mask.reshape(n_w, n_h)
        mask = mask.T
    
        # Update channel of the given error
        image_pixels [:,:,0] = np.logical_or(image_pixels [:,:,0],mask)
        
    return image_pixels

# %% [markdown]
# ## Data generator for train

# %%
# Train Data Generator
def data_generator(ids, batch_size):
    Xs = []; ys = []
    while True:
        for id in ids:
            img = cv2.imread(train_path + id)
            img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
            img = img / 255.
            
            mask = make_mask(id)
            
            img=cv2.resize(img, (int(img.shape[1]/2),int(img.shape[0]/2)), interpolation = cv2.INTER_NEAREST)
            mask=cv2.resize(mask, (int(mask.shape[1]/2),int(mask.shape[0]/2)), interpolation = cv2.INTER_NEAREST)
            
            Xs.append(img); ys.append(mask)
            if len(Xs) == batch_size:
                X = np.array(Xs); y = np.array(ys)
                Xs = []; ys = []
                random.shuffle(ids)
                yield (X, y)

# %%
gen = data_generator(x_train,1)
for i in range(10):
    data =  next(gen)
    plt.imshow(data[0][0])
    plt.show()
    plt.imshow(data[1][0]*128)
    plt.show()

# %% [markdown]
# ## U-Net Model with 4 sigmoid to detect presence or not of each class independently
#
# #### We start with only  1 sigmoid for first training stages to detect only the presence of defect without classification

# %%
def inception_block(prevlayer, a, b):
    
    conva = Conv2D(a, (1, 1), activation='relu', padding='same')(prevlayer)
    conva = Conv2D(b, (3, 3), activation='relu', padding='same')(conva)
    conva = BatchNormalization()(conva)
    
    
    convb = Conv2D(a, (1, 1), activation='relu', padding='same')(prevlayer)
    convb = Conv2D(b, (5, 5), activation='relu', padding='same')(convb)
    convb = BatchNormalization()(convb)

    convc = Conv2D(b, (1, 1), activation='relu', padding='same')(prevlayer)
    convc = BatchNormalization()(convc)
        
    convd = MaxPooling2D(pool_size=(3, 3), strides=(1,1), padding= 'same')(prevlayer)
    convd = Conv2D(b, (1, 1), activation='relu', padding='same')(convd)
    convd = BatchNormalization()(convd)
        
        
    up = concatenate([conva, convb, convc, convd])
    return up

# %%
def build_model(input_layer, start_neurons):
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(input_layer)
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(0.25)(pool1)

    conv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(0.5)(pool2)

    conv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)

    conv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(conv4)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(0.5)(pool4)

    # Mitad
    convm = inception_block (pool4, start_neurons * 4, start_neurons * 4)
    convm = inception_block (convm, start_neurons * 4, start_neurons * 4)
    convm = inception_block (convm, start_neurons * 4, start_neurons * 4)
    
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same",kernel_initializer='he_normal')(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(uconv4)
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(uconv4)

    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same",kernel_initializer='he_normal')(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(uconv3)
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(uconv3)

    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same",kernel_initializer='he_normal')(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(uconv2)

    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same",kernel_initializer='he_normal')(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same",kernel_initializer='he_normal')(uconv1)
    
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid",kernel_initializer='he_normal')(uconv1)
    
    return output_layer

input_layer = Input((128, 800, 1))
output_layer = build_model(input_layer, 16)

model = Model(input_layer, output_layer)

# %% [markdown]
# ### Additional usefull metrics

# %%
smooth = 1
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_multilabel(y_true, y_pred, numLabels):
    dice=0
    for index in range(numLabels):
        dice -= dice_coef(y_true[:,:,index], y_pred[:,:,index])
    return dice

def dice_coef_nd(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return 2.*intersection, (np.sum(y_true_f)+np.sum(y_pred_f))

def dice_loss(y_true,y_pred):
    return (1 - dice_coef(y_true,y_pred))

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

def tversky(y_true, y_pred, smooth=1, alpha=0.7):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1 - y_pred_pos))
    false_pos = K.sum((1 - y_true_pos) * y_pred_pos)
    return (1 - ((true_pos + smooth) / (true_pos + alpha * false_neg + (1 - alpha) * false_pos + smooth)))

# %%
optimizer = Adam()
#model.compile(loss=tversky, optimizer=optimizer, metrics=[dice_coef])
#model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[dice_coef])
model.compile(optimizer, dice_loss, metrics=[dice_coef,MeanIoU(num_classes=2),'accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 128, 800, 1) 0
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 128, 800, 16) 160         input_8[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 128, 800, 16) 2320        conv2d_119[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 64, 400, 16)  0           conv2d_120[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 64, 400, 16)  0           max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 64, 400, 32)  4640        dropout_48[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 64, 400, 32)  9248        conv2d_121[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 32, 200, 32)  0           conv2d_122[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 32, 200, 32)  0           max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 32, 200, 64)  18496       dropout_49[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 32, 200, 64)  36928       conv2d_123[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 16, 100, 64)  0           conv2d_124[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 16, 100, 64)  0           max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 16, 100, 128) 73856       dropout_50[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 16, 100, 128) 147584      conv2d_125[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 8, 50, 128)   0           conv2d_126[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 8, 50, 128)   0           max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 8, 50, 64)    8256        dropout_51[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 8, 50, 64)    8256        dropout_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 8, 50, 128)   0           dropout_51[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 8, 50, 64)    36928       conv2d_127[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 8, 50, 64)    102464      conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 8, 50, 64)    8256        dropout_51[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 8, 50, 64)    8256        max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 50, 64)    256         conv2d_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 50, 64)    256         conv2d_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 50, 64)    256         conv2d_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 50, 64)    256         conv2d_132[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 8, 50, 256)   0           batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 8, 50, 64)    16448       concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 8, 50, 64)    16448       concatenate_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 8, 50, 256)   0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 8, 50, 64)    36928       conv2d_133[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 8, 50, 64)    102464      conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 8, 50, 64)    16448       concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 8, 50, 64)    16448       max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 50, 64)    256         conv2d_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 50, 64)    256         conv2d_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 50, 64)    256         conv2d_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 50, 64)    256         conv2d_138[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 8, 50, 256)   0           batch_normalization_8[0][0]
#                                                                  batch_normalization_9[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 8, 50, 64)    16448       concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 8, 50, 64)    16448       concatenate_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 8, 50, 256)   0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 8, 50, 64)    36928       conv2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 8, 50, 64)    102464      conv2d_141[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 8, 50, 64)    16448       concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 8, 50, 64)    16448       max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 50, 64)    256         conv2d_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 50, 64)    256         conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 50, 64)    256         conv2d_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 50, 64)    256         conv2d_144[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 8, 50, 256)   0           batch_normalization_12[0][0]
#                                                                  batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 16, 100, 128) 295040      concatenate_23[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 16, 100, 256) 0           conv2d_transpose_20[0][0]
#                                                                  conv2d_126[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 16, 100, 256) 0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 16, 100, 128) 295040      dropout_52[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 16, 100, 128) 147584      conv2d_145[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 32, 200, 64)  73792       conv2d_146[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 32, 200, 128) 0           conv2d_transpose_21[0][0]
#                                                                  conv2d_124[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 32, 200, 128) 0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 32, 200, 64)  73792       dropout_53[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 32, 200, 64)  36928       conv2d_147[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 64, 400, 32)  18464       conv2d_148[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 64, 400, 64)  0           conv2d_transpose_22[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 64, 400, 64)  0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 64, 400, 32)  18464       dropout_54[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 64, 400, 32)  9248        conv2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 128, 800, 16) 4624        conv2d_150[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 128, 800, 32) 0           conv2d_transpose_23[0][0]
#                                                                  conv2d_120[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 128, 800, 32) 0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 128, 800, 16) 4624        dropout_55[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 128, 800, 16) 2320        conv2d_151[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 128, 800, 1)  17          conv2d_152[0][0]
# ==================================================================================================
# Total params: 1,859,025
# Trainable params: 1,857,489
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %% [markdown]
# ### Model Train

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1)

epochs = 10
batch_size = 16

train_generator = data_generator(x_train, batch_size)
validation_generator = data_generator(x_valid, batch_size)

train_steps_per_epoch=int(len(x_train)/batch_size)
validation_steps_per_epoch=int(len(x_valid)/batch_size)

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=train_steps_per_epoch,
                              epochs=epochs,
                              validation_data = validation_generator,
                              validation_steps = validation_steps_per_epoch
                              #callbacks=[early_stopping, model_checkpoint, reduce_lr])
                             )
# Out:
# Epoch 1/10
# 371/371 [==============================] - 149s 402ms/step - loss: 0.3735 - dice_coef: 0.6265 - mean_io_u_8: 0.6985 - accuracy: 0.9602 - val_loss: 0.4327 - val_dice_coef: 0.5673 - val_mean_io_u_8: 0.6726 - val_accuracy: 0.9584
# Epoch 2/10
# 371/371 [==============================] - 150s 405ms/step - loss: 0.3677 - dice_coef: 0.6323 - mean_io_u_8: 0.7132 - accuracy: 0.9601 - val_loss: 0.3910 - val_dice_coef: 0.6090 - val_mean_io_u_8: 0.6992 - val_accuracy: 0.9625
# Epoch 3/10
# 371/371 [==============================] - 150s 404ms/step - loss: 0.3523 - dice_coef: 0.6477 - mean_io_u_8: 0.7214 - accuracy: 0.9601 - val_loss: 0.3876 - val_dice_coef: 0.6124 - val_mean_io_u_8: 0.7037 - val_accuracy: 0.9545
# Epoch 4/10
#  54/371 [===>..........................] - ETA: 1:55 - loss: 0.3635 - dice_coef: 0.6365 - mean_io_u_8: 0.7159 - accuracy: 0.9604

# %% [raw]
# model.save_weights('./weights/pre3/model_pre_v3')

# %% [raw]
# model.save('./model/pre3/model_pre3')

# %%
test_generator = data_generator(x_test,batch_size=1)

for i in range(10):
    data_test = next(test_generator)
    prediction=model.predict(data_test[0])
    plt.imshow(data_test[0][0])
    plt.show()
    plt.imshow(data_test[1][0]*128)
    plt.show()
    plt.imshow(prediction[0]*128)
    plt.show()

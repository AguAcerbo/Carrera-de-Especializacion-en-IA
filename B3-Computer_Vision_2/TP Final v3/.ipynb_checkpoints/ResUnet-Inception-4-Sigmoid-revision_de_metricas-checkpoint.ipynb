# %%
import os
import csv
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
import pickle as pkl
import cv2
import numpy as np
from sklearn import model_selection
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout,BatchNormalization, Dense, Add, ReLU
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.metrics import MeanIoU
import random

# %% [markdown]
# ## Check TF GPU

# %%
if tf.test.gpu_device_name(): 
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device:/device:GPU:0

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %% [markdown]
# ## Load csv and paths

# %%
csv_path = r"C:\Users\Agustin\Documents\RepositorioCEIA_Git\VpC2_Datasets\severstal-steel-defect-detection/train.csv"
train_path = r"C:\Users\Agustin\Documents\RepositorioCEIA_Git\VpC2_Datasets\severstal-steel-defect-detection/train_images/"
train_masks_path = r"C:\Users\Agustin\Documents\RepositorioCEIA_Git\VpC2_Datasets\severstal-steel-defect-detection/train_masks/"

csv_reducido = r"C:\Users\Agustin\Documents\RepositorioCEIA_Git\VpC2_Datasets\severstal-steel-defect-detection/train_4sigmoid.csv"

# %%
n_w = 1600
n_h = 256

# %% [markdown]
# ## Create a more balanced dataset with defects and extra 10% without defects

# %%
#defective_csv = pd.read_csv(csv_reducido)

defective_csv = pd.read_csv(csv_path)
all_img = [value for value in listdir(train_path)]
defective_img = [value for value in listdir(train_path) if value in list(defective_csv['ImageId'])]
nondefective_img = [value for value in listdir(train_path) if value not in list(defective_csv['ImageId'])]

# %%
print(len(defective_img))
print(len(nondefective_img))
# Out:
# 6666
# 5902

# %%
idx_aux= np.random.permutation(len(nondefective_img))[0: int(len(defective_img)*0.1)-1]
defective_img = defective_img + [nondefective_img[value] for value in idx_aux]

# %%
len(defective_img)
# Out:
# 7331

# %% [markdown]
# ## Train, Test and Validation

# %%
x_train, x_test = model_selection.train_test_split( defective_img, test_size=0.1, random_state=5)
x_train, x_valid = model_selection.train_test_split( x_train, test_size=0.1, random_state=5)

# %% [markdown]
# ## Functions for inline (RAM) Y defect mask creation

# %%
def decode_pixels(pixels_str):
    """
    This function receives a list which contains the pixels as a space-separated code.
    For example, '1 3 10 5' implies pixels 1,2,3,10,11,12,13,14 are to be included in the mask
    """
    
    pixels_encoded_list = pixels_str.split(' ')
    pixels_list = []
    for i in range(0, len(pixels_encoded_list), 2):
        # Add to the pixels list all the pixels encoded by the 2 digits
        pixels_list += range(
            int(pixels_encoded_list[i]) - 1,
            int(pixels_encoded_list[i]) + int(pixels_encoded_list[i + 1]) - 1,
        )
        
    # Return the decoded list    
    return pixels_list

# %% [markdown]
# ## Data Augmentation Functions

# %%
def flip(image, mask , vflip=False, hflip=False):
    '''
    Flip the image
    :param image: image to be processed
    :param vflip: whether to flip the image vertically
    :param hflip: whether to flip the image horizontally
    '''
    if hflip or vflip:
        if hflip and vflip:
            c = -1
        else:
            c = 0 if vflip else 1
        image = cv2.flip(image, flipCode=c)
        mask = cv2.flip(mask, flipCode=c)
    return image, mask

def rotate(image, mask, angle=90, scale=1.0):
    '''
    Rotate the image
    :param image: image to be processed
    :param angle: Rotation angle in degrees. Positive values mean counter-clockwise rotation (the coordinate origin is assumed to be the top-left corner).
    :param scale: Isotropic scale factor.
    '''
    w = image.shape[1]
    h = image.shape[0]
    #rotate matrix
    M = cv2.getRotationMatrix2D((w/2,h/2), angle, scale)
    #rotate
    image = cv2.warpAffine(image,M,(w,h))
    mask = cv2.warpAffine(mask,M,(w,h))
    return image, mask
    
def shift(image, mask, px, py):
    w = image.shape[1]
    h = image.shape[0]
    #c = image.shape[2]
    
    img = np.zeros((h,w))
    m = np.zeros((h,w))   
    
    if (py > 0) and (px > 0):
        img[py:, px:] = image[:-py, :-px]
        m[py:, px:] = mask[:-py, :-px]
    elif (py < 0) and (px < 0):
        img[:py, :px] = image[-py:, -px:]
        m[:py, :px] = mask[-py:, -px:]
    elif (py > 0) and (px < 0):
        img[py:, :px] = image[:-py, -px:]
        m[py:, :px] = mask[:-py, -px:]
    elif (py < 0) and (px > 0):
        img[:py, px:] = image[-py:, :-px]
        m[:py, px:] = mask[-py:, :-px]
    
    return img, m

# %% [markdown]
# ## Data generator for train

# %%
# Train Data Generator
def data_generator(ids, batch_size):
    Xs = []; ys = []
    
    while True:
        i = 0
        random.shuffle(ids)
        aug_shift = np.random.randint(2, size=len(ids))
        aug_rot = np.random.randint(2, size=len(ids))
        aug_flip = np.random.randint(2, size=len(ids))
        for id in ids:
            img = cv2.imread(train_path + id)
            img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
            img = img / 255.
            
            mask = make_mask(id)
            
            img=cv2.resize(img, (int(img.shape[1]/2),int(img.shape[0]/2)))
            mask=cv2.resize(mask, (int(mask.shape[1]/2),int(mask.shape[0]/2)))
            
            #if aug_shift[i] == 1:
            #    img, mask = shift(img, mask,
            #                      px=np.random.randint(low = -int(img.shape[1]/10),high = int(img.shape[1]/10)),
            #                      py=np.random.randint(low = -int(img.shape[0]/10),high = int(img.shape[0]/10))
            #                     )
            #if aug_rot[i] == 1:
            #    img, mask = rotate(img, mask, angle=np.random.randint(-10,10), scale=1.0 + (random.randint(0,20)/10) )
            #if aug_flip[i] == 1:
            #    img, mask = flip(img, mask, vflip=True, hflip=False)
            #mask = (mask > 0.2) * 1.0
            #
            #i+=1
            
            Xs.append(img); ys.append(mask)
            if len(Xs) == batch_size:
                X = np.array(Xs); y = np.array(ys)
                Xs = []; ys = []
                yield (X, y)

# %% [markdown]
# ### Additional usefull metrics

# %%
smooth = 1
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_multilabel(y_true, y_pred, numLabels=4):
    dice=0
    for index in range(numLabels):
        dice -= dice_coef(y_true[:,:,index], y_pred[:,:,index])
    return dice

def dice_coef_nd(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return 2.*intersection, (np.sum(y_true_f)+np.sum(y_pred_f))

def dice_loss(y_true,y_pred):
    return (1 - dice_coef(y_true,y_pred))

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

def tversky(y_true, y_pred, smooth=1, alpha=0.7):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1 - y_pred_pos))
    false_pos = K.sum((1 - y_true_pos) * y_pred_pos)
    return (1 - ((true_pos + smooth) / (true_pos + alpha * false_neg + (1 - alpha) * false_pos + smooth)))

def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred))
    union = K.sum(y_true)+K.sum(y_pred)-intersection
    iou = K.mean((intersection + smooth) / (union + smooth))
    return iou

# %% [markdown]
# # ResUnet - Inception

# %%
def inception_block(prevlayer, a, b):
    
    conva = Conv2D(a, (1, 1), activation='relu', padding='same')(prevlayer)
    conva = Conv2D(b, (3, 3), activation=None, padding='same')(conva)
    conva = BatchNormalization()(conva)
    conva = ReLU()(conva)
    
    
    convb = Conv2D(a, (1, 1), activation='relu', padding='same')(prevlayer)
    convb = Conv2D(b, (5, 5), activation=None, padding='same')(convb)
    convb = BatchNormalization()(convb)
    convb = ReLU()(convb)

    convc = Conv2D(b, (1, 1), activation=None, padding='same')(prevlayer)
    convc = BatchNormalization()(convc)
    convc = ReLU()(convc)
        
    convd = MaxPooling2D(pool_size=(3, 3), strides=(1,1), padding= 'same')(prevlayer)
    convd = Conv2D(b, (1, 1), activation=None, padding='same')(convd)
    convd = BatchNormalization()(convd)
    convd = ReLU()(convd)
        
        
    up = concatenate([conva, convb, convc, convd])
    return up

# %%
def residual_block (input_layer, neurons):
    
    conv1 = Conv2D(neurons , (5, 5), activation=None, padding="same",kernel_initializer='he_normal')(input_layer)
    conv1 = BatchNormalization()(conv1)
    conv1 = ReLU()(conv1)
    conv1 = Conv2D(neurons, (5, 5), activation=None, padding="same",kernel_initializer='he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = ReLU()(conv1)
    conv1 = Conv2D(neurons, (5, 5), activation=None, padding="same",kernel_initializer='he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    
    conv1_skip = Conv2D(neurons, 1, 1, activation=None, padding="same",kernel_initializer='he_normal')(input_layer)
    conv1_skip = BatchNormalization()(conv1_skip)
    
    added1 = Add()([conv1_skip, conv1])
    relu1 = ReLU()(added1)
    
    return relu1

# %%
def build_model(input_layer, start_neurons):
    
    conv1 = residual_block(input_layer,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    #pool1 = Dropout(0.25)(pool1)

    conv2 = residual_block(pool1,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    #pool2 = Dropout(0.5)(pool2)

    conv3 = residual_block(pool2,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4)
    pool3 = MaxPooling2D((2, 2))(conv3)
    #pool3 = Dropout(0.5)(pool3)

    conv4 = residual_block(pool3,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8)
    pool4 = MaxPooling2D((2, 2))(conv4)
    #pool4 = Dropout(0.5)(pool4)

    # Mitad
    convm = inception_block (pool4, start_neurons * 4, start_neurons * 4)
    convm = inception_block (convm, start_neurons * 4, start_neurons * 4)
    convm = inception_block (convm, start_neurons * 4, start_neurons * 4)
    convm = inception_block (convm, start_neurons * 4, start_neurons * 4)

    deconv4 = Conv2DTranspose(start_neurons * 8, (5, 5), strides=(2, 2), padding="same",kernel_initializer='he_normal')(convm)
    uconv4 = concatenate([deconv4, conv4])
    #uconv4 = Dropout(0.5)(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8)

    deconv3 = Conv2DTranspose(start_neurons * 4, (5, 5), strides=(2, 2), padding="same",kernel_initializer='he_normal')(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    #uconv3 = Dropout(0.5)(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4)

    deconv2 = Conv2DTranspose(start_neurons * 2, (5, 5), strides=(2, 2), padding="same",kernel_initializer='he_normal')(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    #uconv2 = Dropout(0.5)(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2)

    deconv1 = Conv2DTranspose(start_neurons * 1, (5, 5), strides=(2, 2), padding="same",kernel_initializer='he_normal')(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    #uconv1 = Dropout(0.5)(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid",kernel_initializer='he_normal')(uconv1)
    
    return output_layer

input_layer = Input((128, 800, 1))
output_layer = build_model(input_layer, 8)

model = Model(input_layer, output_layer)

# %%
model.load_weights('./weights/resUnetInceptionV5/resUnetInceptionV5')

# %% [markdown]
# ## Model 2
# ## U-Net Model with 4 sigmoid to detect presence or not of each class independently

# %%
n_class = 4
def make_mask(ImageId):
    
    y_out=defective_csv[defective_csv['ImageId'].eq(ImageId)]
    
    image_pixels = np.zeros((n_h, n_w,n_class), dtype=np.float32)

    for index, row in y_out.iterrows():

        # Generate the mask of the error type
        mask = np.zeros((n_h * n_w, 1), dtype=np.float32)
        mask[decode_pixels(row['EncodedPixels'])] = 1
        mask = mask.reshape(n_w, n_h)
        mask = mask.T
    
        # Update channel of the given error
        image_pixels [:,:,int(row['ClassId'])-1] = np.logical_or(image_pixels [:,:,int(row['ClassId'])-1],mask)
        
    return image_pixels

# %%
def build_model2(input_layer, start_neurons):
    
    uconv1 = residual_block(input_layer,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    output_layer1 = Conv2D(1, (1,1), padding="same", activation="sigmoid",kernel_initializer='he_normal')(uconv1)
    
    uconv2 = residual_block(input_layer,start_neurons * 1)
    uconv2 = residual_block(uconv2,start_neurons * 1)
    output_layer2 = Conv2D(1, (1,1), padding="same", activation="sigmoid",kernel_initializer='he_normal')(uconv2)
    
    uconv3 = residual_block(input_layer,start_neurons * 1)
    uconv3 = residual_block(uconv3,start_neurons * 1)
    output_layer3 = Conv2D(1, (1,1), padding="same", activation="sigmoid",kernel_initializer='he_normal')(uconv3)
    
    uconv4 = residual_block(input_layer,start_neurons * 1)
    uconv4 = residual_block(uconv4,start_neurons * 1)
    output_layer4 = Conv2D(1, (1,1), padding="same", activation="sigmoid",kernel_initializer='he_normal')(uconv4)
    
    uconvf = concatenate([output_layer1, output_layer2, output_layer3, output_layer4])
    
    return uconvf

output_layer = build_model2(model.layers[-4].output,4)

model2 = Model(model.layers[0].input, output_layer)

# %%
model2.load_weights('./weights/resUnetInception4Sigmoid_5epocas_v1/resUnetInception4Sigmoid_25epocas_v4')

# %%
optimizer = Adam()
#model2.compile(loss=tversky, optimizer=optimizer, metrics=[dice_coef])
#model2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[dice_coef])
model2.compile(optimizer, dice_loss, metrics=[dice_coef])

# %%
model2.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 800, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 800, 8)  208         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 800, 8)  32          conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 128, 800, 8)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 800, 8)  1608        re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 800, 8)  32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 128, 800, 8)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 800, 8)  16          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 800, 8)  1608        re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 800, 8)  32          conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 800, 8)  32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 800, 8)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 128, 800, 8)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 800, 8)  1608        re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 800, 8)  32          conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 128, 800, 8)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 800, 8)  1608        re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 800, 8)  32          conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 128, 800, 8)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 800, 8)  72          re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 800, 8)  1608        re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 800, 8)  32          conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 800, 8)  32          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 800, 8)  0           batch_normalization_7[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 128, 800, 8)  0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 400, 8)   0           re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 400, 16)  3216        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 400, 16)  64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 64, 400, 16)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 400, 16)  6416        re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 400, 16)  64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 64, 400, 16)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 400, 16)  144         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 400, 16)  6416        re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 400, 16)  64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 400, 16)  64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 400, 16)  0           batch_normalization_11[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 64, 400, 16)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 400, 16)  6416        re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 400, 16)  64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 64, 400, 16)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 400, 16)  6416        re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 400, 16)  64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 64, 400, 16)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 400, 16)  272         re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 400, 16)  6416        re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 400, 16)  64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 400, 16)  64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 400, 16)  0           batch_normalization_15[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 64, 400, 16)  0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 200, 16)  0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 200, 32)  12832       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 200, 32)  128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 32, 200, 32)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 200, 32)  128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 32, 200, 32)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 200, 32)  544         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 200, 32)  128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 200, 32)  128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 200, 32)  0           batch_normalization_19[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 32, 200, 32)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 200, 32)  128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 32, 200, 32)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 200, 32)  128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 32, 200, 32)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 200, 32)  1056        re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 200, 32)  128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 200, 32)  128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 200, 32)  0           batch_normalization_23[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 32, 200, 32)  0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 100, 32)  0           re_lu_17[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 100, 64)  51264       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 100, 64)  256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 16, 100, 64)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 100, 64)  256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 16, 100, 64)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 100, 64)  2112        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 100, 64)  256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 100, 64)  256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 100, 64)  0           batch_normalization_27[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 16, 100, 64)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 100, 64)  256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 16, 100, 64)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 100, 64)  256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 16, 100, 64)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 100, 64)  4160        re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 100, 64)  256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 100, 64)  256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 100, 64)  0           batch_normalization_31[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 16, 100, 64)  0           add_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 50, 64)    0           re_lu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 50, 32)    2080        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 50, 32)    2080        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 50, 64)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 50, 32)    9248        conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 50, 32)    25632       conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 50, 32)    2080        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 50, 32)    2080        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 50, 32)    128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 50, 32)    128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 50, 32)    128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 50, 32)    128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 50, 128)   0           re_lu_24[0][0]
#                                                                  re_lu_25[0][0]
#                                                                  re_lu_26[0][0]
#                                                                  re_lu_27[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 50, 32)    4128        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 50, 32)    4128        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 50, 128)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 50, 32)    9248        conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 50, 32)    25632       conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 50, 32)    4128        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 50, 32)    4128        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 50, 32)    128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 50, 32)    128         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 50, 32)    128         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 50, 32)    128         conv2d_43[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 50, 128)   0           re_lu_28[0][0]
#                                                                  re_lu_29[0][0]
#                                                                  re_lu_30[0][0]
#                                                                  re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 50, 32)    4128        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 50, 32)    4128        concatenate_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 8, 50, 128)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 50, 32)    9248        conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 50, 32)    25632       conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 50, 32)    4128        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 50, 32)    4128        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 50, 32)    128         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 50, 32)    128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 50, 32)    128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 50, 32)    128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 50, 128)   0           re_lu_32[0][0]
#                                                                  re_lu_33[0][0]
#                                                                  re_lu_34[0][0]
#                                                                  re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 50, 32)    4128        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 50, 32)    4128        concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 50, 128)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 50, 32)    9248        conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 50, 32)    25632       conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 50, 32)    4128        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 50, 32)    4128        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8, 50, 32)    128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 50, 32)    128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8, 50, 32)    128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 8, 50, 32)    128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 8, 50, 32)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 50, 128)   0           re_lu_36[0][0]
#                                                                  re_lu_37[0][0]
#                                                                  re_lu_38[0][0]
#                                                                  re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 100, 64)  204864      concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 100, 128) 0           conv2d_transpose[0][0]
#                                                                  re_lu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 100, 64)  204864      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 100, 64)  256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 16, 100, 64)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 100, 64)  256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 16, 100, 64)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 16, 100, 64)  8256        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 100, 64)  256         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 100, 64)  256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 100, 64)  0           batch_normalization_51[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 16, 100, 64)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 16, 100, 64)  256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, 16, 100, 64)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 16, 100, 64)  256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 16, 100, 64)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 16, 100, 64)  4160        re_lu_42[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 16, 100, 64)  102464      re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 16, 100, 64)  256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 16, 100, 64)  256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 100, 64)  0           batch_normalization_55[0][0]
#                                                                  batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 16, 100, 64)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 200, 32)  51232       re_lu_45[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 200, 64)  0           conv2d_transpose_1[0][0]
#                                                                  re_lu_17[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 200, 32)  51232       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 32, 200, 32)  128         conv2d_64[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 32, 200, 32)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 200, 32)  128         conv2d_65[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, 32, 200, 32)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 200, 32)  2080        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 200, 32)  128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 200, 32)  128         conv2d_66[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 200, 32)  0           batch_normalization_59[0][0]
#                                                                  batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 32, 200, 32)  0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 200, 32)  128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, 32, 200, 32)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 200, 32)  128         conv2d_69[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 32, 200, 32)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 200, 32)  1056        re_lu_48[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 200, 32)  25632       re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 200, 32)  128         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 200, 32)  128         conv2d_70[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 200, 32)  0           batch_normalization_63[0][0]
#                                                                  batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 32, 200, 32)  0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 400, 16)  12816       re_lu_51[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 400, 32)  0           conv2d_transpose_2[0][0]
#                                                                  re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 64, 400, 16)  12816       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 64, 400, 16)  64          conv2d_72[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, 64, 400, 16)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 64, 400, 16)  6416        re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 64, 400, 16)  64          conv2d_73[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, 64, 400, 16)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 64, 400, 16)  528         concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 64, 400, 16)  6416        re_lu_53[0][0]
# __________________________________________________________________________________________________
# ...
# conv2d_100 (Conv2D)             (None, 128, 800, 4)  404         re_lu_71[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 128, 800, 4)  36          batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 128, 800, 4)  404         re_lu_77[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 128, 800, 4)  36          batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 128, 800, 4)  404         re_lu_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 128, 800, 4)  16          conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 128, 800, 4)  16          conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 128, 800, 4)  16          conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 128, 800, 4)  16          conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 128, 800, 4)  16          conv2d_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 128, 800, 4)  16          conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 128, 800, 4)  16          conv2d_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 128, 800, 4)  16          conv2d_118[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 128, 800, 4)  0           batch_normalization_83[0][0]
#                                                                  batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 128, 800, 4)  0           batch_normalization_91[0][0]
#                                                                  batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 128, 800, 4)  0           batch_normalization_99[0][0]
#                                                                  batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 128, 800, 4)  0           batch_normalization_107[0][0]
#                                                                  batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# re_lu_66 (ReLU)                 (None, 128, 800, 4)  0           add_16[0][0]
# __________________________________________________________________________________________________
# re_lu_72 (ReLU)                 (None, 128, 800, 4)  0           add_18[0][0]
# __________________________________________________________________________________________________
# re_lu_78 (ReLU)                 (None, 128, 800, 4)  0           add_20[0][0]
# __________________________________________________________________________________________________
# re_lu_84 (ReLU)                 (None, 128, 800, 4)  0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 128, 800, 4)  404         re_lu_66[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 128, 800, 4)  404         re_lu_72[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 128, 800, 4)  404         re_lu_78[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 128, 800, 4)  404         re_lu_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 128, 800, 4)  16          conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 128, 800, 4)  16          conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 128, 800, 4)  16          conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 128, 800, 4)  16          conv2d_120[0][0]
# __________________________________________________________________________________________________
# re_lu_67 (ReLU)                 (None, 128, 800, 4)  0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# re_lu_73 (ReLU)                 (None, 128, 800, 4)  0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# re_lu_79 (ReLU)                 (None, 128, 800, 4)  0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# re_lu_85 (ReLU)                 (None, 128, 800, 4)  0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 128, 800, 4)  404         re_lu_67[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 128, 800, 4)  404         re_lu_73[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 128, 800, 4)  404         re_lu_79[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 128, 800, 4)  404         re_lu_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 128, 800, 4)  16          conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 128, 800, 4)  16          conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 128, 800, 4)  16          conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 128, 800, 4)  16          conv2d_121[0][0]
# __________________________________________________________________________________________________
# re_lu_68 (ReLU)                 (None, 128, 800, 4)  0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# re_lu_74 (ReLU)                 (None, 128, 800, 4)  0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# re_lu_80 (ReLU)                 (None, 128, 800, 4)  0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# re_lu_86 (ReLU)                 (None, 128, 800, 4)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 128, 800, 4)  20          re_lu_66[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 128, 800, 4)  404         re_lu_68[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 128, 800, 4)  20          re_lu_72[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 128, 800, 4)  404         re_lu_74[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 128, 800, 4)  20          re_lu_78[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 128, 800, 4)  404         re_lu_80[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 128, 800, 4)  20          re_lu_84[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 128, 800, 4)  404         re_lu_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 128, 800, 4)  16          conv2d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 128, 800, 4)  16          conv2d_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 128, 800, 4)  16          conv2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 128, 800, 4)  16          conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 128, 800, 4)  16          conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 128, 800, 4)  16          conv2d_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 128, 800, 4)  16          conv2d_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 128, 800, 4)  16          conv2d_122[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 128, 800, 4)  0           batch_normalization_87[0][0]
#                                                                  batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 128, 800, 4)  0           batch_normalization_95[0][0]
#                                                                  batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 128, 800, 4)  0           batch_normalization_103[0][0]
#                                                                  batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 128, 800, 4)  0           batch_normalization_111[0][0]
#                                                                  batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# re_lu_69 (ReLU)                 (None, 128, 800, 4)  0           add_17[0][0]
# __________________________________________________________________________________________________
# re_lu_75 (ReLU)                 (None, 128, 800, 4)  0           add_19[0][0]
# __________________________________________________________________________________________________
# re_lu_81 (ReLU)                 (None, 128, 800, 4)  0           add_21[0][0]
# __________________________________________________________________________________________________
# re_lu_87 (ReLU)                 (None, 128, 800, 4)  0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 128, 800, 1)  5           re_lu_69[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 128, 800, 1)  5           re_lu_75[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 128, 800, 1)  5           re_lu_81[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 128, 800, 1)  5           re_lu_87[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 800, 4)  0           conv2d_97[0][0]
#                                                                  conv2d_106[0][0]
#                                                                  conv2d_115[0][0]
#                                                                  conv2d_124[0][0]
# ==================================================================================================
# Total params: 2,216,948
# Trainable params: 2,211,844
# Non-trainable params: 5,104
# __________________________________________________________________________________________________

# %% [raw]
# epochs = 25
# batch_size = 16
#
# train_generator = data_generator(x_train, batch_size)
# validation_generator = data_generator(x_valid, batch_size)
#
# train_steps_per_epoch=int(len(x_train)/batch_size)
# validation_steps_per_epoch=int(len(x_valid)/batch_size)
#
# history = model2.fit_generator(generator=train_generator,
#                                steps_per_epoch=train_steps_per_epoch,
#                                epochs=epochs,
#                                validation_data = validation_generator,
#                                validation_steps = validation_steps_per_epoch
#                                #callbacks=[early_stopping, model_checkpoint, reduce_lr])
#                               )

# %% [raw]
# model2.save_weights('./weights/resUnetInception4Sigmoid_5epocas_v1/resUnetInception4Sigmoid_25epocas_v4')

# %%
test_generator = data_generator(x_test,batch_size=1)

iou_total = 0
iou_keras_total = 0
dice_total = 0

for i in range(10):
    data_test = next(test_generator)
    prediction=model2.predict(data_test[0])
    plt.imshow(data_test[0][0],cmap='gray', vmin=0, vmax=1)
    plt.show()
    
    iou = 0
    dice_1 = 0

    y_pred_keras = []
    y_true_keras = []
    for j in range(data_test[1][0].shape[2]):
        y_true = data_test[1][0][:,:,j]
        y_pred = prediction[0][:,:,j]
        
        y_pred = (y_pred[:, :] > 0.5) * y_pred
        
        print(f"Falla tipo: {j+1} - IOU: {iou_coef(K.flatten(y_true), K.flatten(y_pred), smooth=1).numpy()} - DICE: {dice_coef(y_true, y_pred).numpy()}")
        iou += iou_coef(K.flatten(y_true), K.flatten(y_pred), smooth=1).numpy()
        dice_1 += dice_coef(y_true, y_pred).numpy()
        plt.imshow(y_true)
        plt.show()
        plt.imshow(y_pred)
        plt.show()
        
        y_pred_keras.append(y_pred)
        y_true_keras.append(y_true)
        
    print(f"Mean IOU: {iou/4}")
    print(f"Mean DICE: {dice_1/4}")

    m = tf.keras.metrics.MeanIoU(num_classes=4)
    m.update_state(y_true_keras, y_pred_keras).numpy()
    #m.update_state([data_test[1][0][:,:,0], data_test[1][0][:,:,1], data_test[1][0][:,:,2], data_test[1][0][:,:,3]],
    #                [prediction[0][:,:,0], prediction[0][:,:,1], prediction[0][:,:,2], prediction[0][:,:,3]]).numpy()
    print(f"Keras-IOU: {m.result().numpy()}")
    
    
    iou_total += iou/4
    iou_keras_total += dice_1/4
    dice_total += m.result().numpy()

print()
print(f"Mean IOU Total: {iou_total/10}")
print(f"Mean DICE Total: {dice_total/10}")
print(f"Keras-IOU Total: {iou_keras_total/10}")
# Out:
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.18306492269039154 - DICE: 0.3094607889652252
# Falla tipo: 4 - IOU: 0.0007821816834621131 - DICE: 0.0007821816834621131
# Mean IOU: 0.5459617760934634
# Mean DICE: 0.5775607426621718
# Keras-IOU: 0.4598769247531891
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.00011491047916933894 - DICE: 0.00011491047916933894
# Mean IOU: 0.7500287276197923
# Mean DICE: 0.7500287276197923
# Keras-IOU: 0.49671265482902527
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0002947244211100042 - DICE: 0.0002947244211100042
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7500736811052775
# Mean DICE: 0.7500736811052775
# Keras-IOU: 0.4959387183189392
# Falla tipo: 1 - IOU: 0.0014194464311003685 - DICE: 0.0014194464311003685
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503548616077751
# Mean DICE: 0.7503548616077751
# Keras-IOU: 0.4991748034954071
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.002719238633289933 - DICE: 0.002719238633289933
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7506798096583225
# Mean DICE: 0.7506798096583225
# Keras-IOU: 0.4996386766433716
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5638827681541443 - DICE: 0.7210142612457275
# Falla tipo: 4 - IOU: 0.015914693474769592 - DICE: 0.015914693474769592
# Mean IOU: 0.6449493654072285
# Mean DICE: 0.6842322386801243
# Keras-IOU: 0.7412905693054199
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6873775124549866 - DICE: 0.8147264719009399
# Falla tipo: 4 - IOU: 0.0006829834310337901 - DICE: 0.0006829834310337901
# Mean IOU: 0.6720151239715051
# Mean DICE: 0.7038523638329934
# Keras-IOU: 0.6828874349594116
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0002213981351815164 - DICE: 0.0002213981351815164
# Falla tipo: 4 - IOU: 0.0003562774509191513 - DICE: 0.0003562774509191513
# Mean IOU: 0.5001444188965252
# Mean DICE: 0.5001444188965252
# Keras-IOU: 0.49278441071510315
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5913851857185364 - DICE: 0.7431332468986511
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8978462964296341
# Mean DICE: 0.9357833117246628
# Keras-IOU: 0.7831186056137085
#
# Mean IOU Total: 0.7262054060789523
# Mean DICE Total: 0.6151422798633576
# Keras-IOU Total: 0.7402710155787645

# %%
test_generator = data_generator(x_test,batch_size=1)

tpn=0
total = 0
intersection = 0
union = 0
acum_sum=0

for i in range(len(x_test)):
    
    data_test = next(test_generator)
    y_true = data_test[1]
    y_pred =  model2.predict(data_test[0])
    y_pred = (y_pred[:, :] > 0.5) * y_pred

    #Pixel Accuracy
    tpn += np.sum(y_true==y_pred) / y_true.shape[3]
    total += y_true.shape[1]*y_true.shape[2]
    
    intersection += np.sum(y_true * y_pred,axis=(1,2))
    union += np.sum(np.logical_or(y_true,y_pred), axis=(1,2))
    
    acum_sum += np.sum(y_true, axis=(1,2)) + np.sum(y_pred, axis=(1,2))
    
pixel_accuracy = tpn/total

union[union==0]=1
mean_iou = (intersection / union)
    
acum_sum[acum_sum==0]=1
dice = (2* intersection / acum_sum)

# %%
test_generator = data_generator(all_img,batch_size=1)

tpn=0
total = 0
intersection = 0
union = 0
acum_sum=0
dice2=0

for i in range(len(all_img)):
    
    data_test = next(test_generator)
    y_true = data_test[1]
    y_pred = model2.predict(data_test[0])
    y_pred = (y_pred[:, :] > 0.5) * y_pred
    
    #Pixel Accuracy
    tpn += np.sum(y_true==y_pred) / y_true.shape[3]
    total += y_true.shape[1]*y_true.shape[2]
    
    intersection += np.sum(y_true * y_pred,axis=(1,2))
    union += np.sum(np.logical_or(y_true,y_pred), axis=(1,2))
    
    acum_sum += np.sum(y_true, axis=(1,2)) + np.sum(y_pred, axis=(1,2))
    
    dice2 += dice_loss(y_true,model2.predict(data_test[0]))
    
    
pixel_accuracy = tpn/total

union[union==0]=1
mean_iou = (intersection / union)
    
acum_sum[acum_sum==0]=1
dice = (2* intersection / acum_sum)

# %%
test_generator = data_generator(x_test,batch_size=1)

iou_total = 0
iou_keras_total = 0
dice_total = 0

for i in range(len(x_test)):
    data_test = next(test_generator)
    prediction=model2.predict(data_test[0])
    
    iou = 0
    dice_1 = 0

    y_pred_keras = []
    y_true_keras = []
    for j in range(data_test[1][0].shape[2]):
        y_true = data_test[1][0][:,:,j]
        y_pred = prediction[0][:,:,j]
        y_pred = (y_pred[:, :] > 0.5) * y_pred
        
        print(f"Falla tipo: {j+1} - IOU: {iou_coef(K.flatten(y_true), K.flatten(y_pred), smooth=1).numpy()} - DICE: {dice_coef(y_true, y_pred).numpy()}")
        iou += iou_coef(K.flatten(y_true), K.flatten(y_pred), smooth=1).numpy()
        dice_1 += dice_coef(y_true, y_pred).numpy()

        y_pred_keras.append(y_pred)
        y_true_keras.append(y_true)
    
    m = tf.keras.metrics.MeanIoU(num_classes=4)
    m.update_state(y_true_keras, y_pred_keras).numpy()
    
    print(f"Mean IOU: {iou/4}")
    print(f"Mean DICE: {dice_1/4}")
    print(f"Keras-IOU: {m.result().numpy()}")
    print()
    iou_total += iou/4
    iou_keras_total += dice_1/4
    dice_total += m.result().numpy()

print(f"Mean IOU Total: {iou_total/len(x_test)}")
print(f"Mean DICE Total: {dice_total/len(x_test)}")
print(f"Keras-IOU Total: {iou_keras_total/len(x_test)}")
# Out:
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.000815328152384609 - DICE: 0.000815328152384609
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7502038320380962
# Mean DICE: 0.7502038320380962
# Keras-IOU: 0.49858397245407104
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0007920791977085173 - DICE: 0.0007920791977085173
# Falla tipo: 4 - IOU: 0.5089337229728699 - DICE: 0.6745125651359558
# Mean IOU: 0.6274314505426446
# Mean DICE: 0.6688261610834161
# Keras-IOU: 0.6372185945510864
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.22005729377269745 - DICE: 0.36006131768226624
# Falla tipo: 4 - IOU: 0.015238543041050434 - DICE: 0.015238543041050434
# Mean IOU: 0.558823959203437
# Mean DICE: 0.5938249651808292
# Keras-IOU: 0.49925535917282104
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.8297469019889832 - DICE: 0.906946063041687
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9574367254972458
# Mean DICE: 0.9767365157604218
# Keras-IOU: 0.903380274772644
#
# Falla tipo: 1 - IOU: 0.0007476635510101914 - DICE: 0.0007476635510101914
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7501869158877525
# Mean DICE: 0.7501869158877525
# Keras-IOU: 0.49845582246780396
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0004216296074446291 - DICE: 0.0004216296074446291
# Falla tipo: 4 - IOU: 0.7976579070091248 - DICE: 0.8874382376670837
# Mean IOU: 0.6995198841541423
# Mean DICE: 0.7219649668186321
# Keras-IOU: 0.8595730066299438
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6318623423576355 - DICE: 0.7743433117866516
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9079655855894089
# Mean DICE: 0.9435858279466629
# Keras-IOU: 0.7098897695541382
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5732461214065552 - DICE: 0.7286931872367859
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8933115303516388
# Mean DICE: 0.9321732968091965
# Keras-IOU: 0.8225187063217163
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7098420858383179 - DICE: 0.830277144908905
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9274605214595795
# Mean DICE: 0.9575692862272263
# Keras-IOU: 0.780254602432251
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.7812212109565735 - DICE: 0.8771584630012512
# Mean IOU: 0.9453053027391434
# Mean DICE: 0.9692896157503128
# Keras-IOU: 0.7166907787322998
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6178600788116455 - DICE: 0.7637895345687866
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9044650197029114
# Mean DICE: 0.9409473836421967
# Keras-IOU: 0.6995435357093811
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5177274346351624 - DICE: 0.6821813583374023
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8794318586587906
# Mean DICE: 0.9205453395843506
# Keras-IOU: 0.6118667721748352
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0001742615713737905 - DICE: 0.0001742615713737905
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7500435653928434
# Mean DICE: 0.7500435653928434
# Keras-IOU: 0.49311402440071106
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.07486884295940399 - DICE: 0.13919271528720856
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.768717210739851
# Mean DICE: 0.7847981788218021
# Keras-IOU: 0.49477604031562805
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.003000750206410885 - DICE: 0.003000750206410885
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7507501875516027
# Mean DICE: 0.7507501875516027
# Keras-IOU: 0.49962401390075684
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.4361506700515747 - DICE: 0.6073728799819946
# Falla tipo: 4 - IOU: 0.0007556676864624023 - DICE: 0.0007556676864624023
# Mean IOU: 0.6092265844345093
# Mean DICE: 0.6520321369171143
# Keras-IOU: 0.5491485595703125
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.729435384273529 - DICE: 0.8435303568840027
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9323588460683823
# Mean DICE: 0.9608825892210007
# Keras-IOU: 0.8716927766799927
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.2157173454761505 - DICE: 0.3544115424156189
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8039293363690376
# Mean DICE: 0.8386028856039047
# Keras-IOU: 0.49916136264801025
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0012738853693008423 - DICE: 0.0012738853693008423
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503184713423252
# Mean DICE: 0.7503184713423252
# Keras-IOU: 0.4991076588630676
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7721681594848633 - DICE: 0.8714005351066589
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9430420398712158
# Mean DICE: 0.9678501337766647
# Keras-IOU: 0.8761327862739563
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.004115226212888956 - DICE: 0.004115226212888956
# Falla tipo: 4 - IOU: 0.007341424468904734 - DICE: 0.007341424468904734
# Mean IOU: 0.5028641626704484
# Mean DICE: 0.5028641626704484
# Keras-IOU: 0.4997277855873108
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0015618898905813694 - DICE: 0.0015618898905813694
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503904724726453
# Mean DICE: 0.7503904724726453
# Keras-IOU: 0.4992626905441284
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0008348987903445959 - DICE: 0.0008348987903445959
# Falla tipo: 4 - IOU: 0.001025046338327229 - DICE: 0.001025046338327229
# Mean IOU: 0.500464986282168
# Mean DICE: 0.500464986282168
# Keras-IOU: 0.49857544898986816
#
# Falla tipo: 1 - IOU: 0.0017452007159590721 - DICE: 0.0017452007159590721
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7504363001789898
# Mean DICE: 0.7504363001789898
# Keras-IOU: 0.49934446811676025
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.00038521335227414966 - DICE: 0.00038521335227414966
# Mean IOU: 0.7500963033380685
# Mean DICE: 0.7500963033380685
# Keras-IOU: 0.4985705614089966
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.06012774258852005 - DICE: 0.11338696628808975
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.76503193564713
# Mean DICE: 0.7783467415720224
# Keras-IOU: 0.5062549114227295
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0008526966557838023 - DICE: 0.0008526966557838023
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.750213174163946
# Mean DICE: 0.750213174163946
# Keras-IOU: 0.49866700172424316
#
# Falla tipo: 1 - IOU: 0.0006492452812381089 - DICE: 0.0006492452812381089
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7501623113203095
# Mean DICE: 0.7501623113203095
# Keras-IOU: 0.4982617199420929
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7181591987609863 - DICE: 0.8358317613601685
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9295397996902466
# Mean DICE: 0.9589579403400421
# Keras-IOU: 0.6276118755340576
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.1311844438314438 - DICE: 0.23189258575439453
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.782796110957861
# Mean DICE: 0.8079731464385986
# Keras-IOU: 0.48360228538513184
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.2774776518344879 - DICE: 0.4339292049407959
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.819369412958622
# Mean DICE: 0.858482301235199
# Keras-IOU: 0.49964356422424316
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.1768917739391327 - DICE: 0.30059364438056946
# Falla tipo: 4 - IOU: 0.0001477346959291026 - DICE: 0.0001477346959291026
# Mean IOU: 0.5442598771587654
# Mean DICE: 0.5751853447691246
# Keras-IOU: 0.46997448801994324
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 0.0009689922444522381 - DICE: 0.0009689922444522381
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7502422480611131
# Mean DICE: 0.7502422480611131
# Keras-IOU: 0.49885499477386475
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6108945608139038 - DICE: 0.7584084272384644
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.902723640203476
# Mean DICE: 0.9396021068096161
# Keras-IOU: 0.8238591551780701
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.001107113203033805 - DICE: 0.001107113203033805
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7502767783007585
# Mean DICE: 0.7502767783007585
# Keras-IOU: 0.49895262718200684
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.1952824890613556 - DICE: 0.3265102505683899
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7988206222653389
# Mean DICE: 0.8316275626420975
# Keras-IOU: 0.4975598156452179
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.4400084614753723 - DICE: 0.6110813021659851
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8600021153688431
# Mean DICE: 0.9027703255414963
# Keras-IOU: 0.7354159951210022
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.2610495388507843 - DICE: 0.4138883352279663
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8152623847126961
# Mean DICE: 0.8534720838069916
# Keras-IOU: 0.6114146113395691
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5896713137626648 - DICE: 0.7418433427810669
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8974178284406662
# Mean DICE: 0.9354608356952667
# Keras-IOU: 0.7438496947288513
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6459682583808899 - DICE: 0.7848802208900452
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9114920645952225
# Mean DICE: 0.9462200552225113
# Keras-IOU: 0.8128652572631836
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.14478380978107452 - DICE: 0.252717524766922
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7861959524452686
# Mean DICE: 0.8131793811917305
# Keras-IOU: 0.49693238735198975
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 0.004415011033415794 - DICE: 0.004415011033415794
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.751103752758354
# Mean DICE: 0.751103752758354
# Keras-IOU: 0.4997497498989105
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.3342319428920746 - DICE: 0.5009574294090271
# Falla tipo: 4 - IOU: 0.0014464970445260406 - DICE: 0.0014464970445260406
# Mean IOU: 0.5839196099841502
# Mean DICE: 0.6256009816133883
# Keras-IOU: 0.49180543422698975
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 9.772536577656865e-05 - DICE: 9.772536577656865e-05
# Mean IOU: 0.7500244313414441
# Mean DICE: 0.7500244313414441
# Keras-IOU: 0.4956628382205963
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5212806463241577 - DICE: 0.6853048205375671
# Falla tipo: 4 - IOU: 0.03594136983156204 - DICE: 0.03594136983156204
# Mean IOU: 0.6393055040389299
# Mean DICE: 0.6803115475922823
# Keras-IOU: 0.5532037019729614
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.32618555426597595 - DICE: 0.4918527603149414
# Mean IOU: 0.831546388566494
# Mean DICE: 0.8729631900787354
# Keras-IOU: 0.4926098585128784
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7682761549949646 - DICE: 0.8689472079277039
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9420690387487411
# Mean DICE: 0.967236801981926
# Keras-IOU: 0.8377507925033569
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.7655580043792725 - DICE: 0.8672102093696594
# Mean IOU: 0.9413895010948181
# Mean DICE: 0.9668025523424149
# Keras-IOU: 0.8210643529891968
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.000572164193727076 - DICE: 0.000572164193727076
# Falla tipo: 4 - IOU: 0.0010846968507394195 - DICE: 0.0010846968507394195
# Mean IOU: 0.5004142152611166
# Mean DICE: 0.5004142152611166
# Keras-IOU: 0.49797362089157104
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0007511737057939172 - DICE: 0.0007511737057939172
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7501877934264485
# Mean DICE: 0.7501877934264485
# Keras-IOU: 0.49847412109375
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 7.350509258685634e-05 - DICE: 7.350509258685634e-05
# Falla tipo: 4 - IOU: 0.00022276128584053367 - DICE: 0.00022276128584053367
# Mean IOU: 0.5000740665946068
# Mean DICE: 0.5000740665946068
# Keras-IOU: 0.48079589009284973
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.1827259212732315 - DICE: 0.30885687470436096
# Falla tipo: 4 - IOU: 0.0017880602972581983 - DICE: 0.0017880602972581983
# Mean IOU: 0.5461284953926224
# Mean DICE: 0.5776612337504048
# Keras-IOU: 0.535277247428894
#
# Falla tipo: 1 - IOU: 0.001660440000705421 - DICE: 0.001660440000705421
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7504151100001764
# Mean DICE: 0.7504151100001764
# Keras-IOU: 0.49930787086486816
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 0.0016339869471266866 - DICE: 0.0016339869471266866
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7504084967367817
# Mean DICE: 0.7504084967367817
# Keras-IOU: 0.4993029832839966
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.7273834347724915 - DICE: 0.8421728014945984
# Mean IOU: 0.9318458586931229
# Mean DICE: 0.9605432003736496
# Keras-IOU: 0.8268833160400391
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.0007030824199318886 - DICE: 0.0007030824199318886
# Mean IOU: 0.750175770604983
# Mean DICE: 0.750175770604983
# Keras-IOU: 0.4997827112674713
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.46361348032951355 - DICE: 0.6334298253059387
# Falla tipo: 4 - IOU: 0.0034024850465357304 - DICE: 0.0034024850465357304
# Mean IOU: 0.6167539913440123
# Mean DICE: 0.6592080775881186
# Keras-IOU: 0.6663051247596741
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7566341161727905 - DICE: 0.8614414930343628
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9391585290431976
# Mean DICE: 0.9653603732585907
# Keras-IOU: 0.8342170119285583
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.4551788866519928 - DICE: 0.6251963376998901
# Falla tipo: 4 - IOU: 6.433697853935882e-05 - DICE: 6.433697853935882e-05
# Mean IOU: 0.613810805907633
# Mean DICE: 0.6563151686696074
# Keras-IOU: 0.49856579303741455
#
# Falla tipo: 1 - IOU: 0.00179131212644279 - DICE: 0.00179131212644279
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7504478280316107
# Mean DICE: 0.7504478280316107
# Keras-IOU: 0.49937012791633606
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.001106662442907691 - DICE: 0.001106662442907691
# Falla tipo: 4 - IOU: 0.7215198874473572 - DICE: 0.8382085561752319
# Mean IOU: 0.6806566374725662
# Mean DICE: 0.7098288046545349
# Keras-IOU: 0.8001977205276489
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5630471706390381 - DICE: 0.7204102277755737
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8907617926597595
# Mean DICE: 0.9301025569438934
# Keras-IOU: 0.6858161687850952
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.13182592391967773 - DICE: 0.23265905678272247
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7829564809799194
# Mean DICE: 0.8081647641956806
# Keras-IOU: 0.49751463532447815
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.004089979454874992 - DICE: 0.004089979454874992
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7510224948637187
# Mean DICE: 0.7510224948637187
# Keras-IOU: 0.4997290074825287
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.3550131022930145 - DICE: 0.5238999128341675
# Falla tipo: 4 - IOU: 0.6307615637779236 - DICE: 0.6307615637779236
# Mean IOU: 0.7464436665177345
# Mean DICE: 0.7886653691530228
# Keras-IOU: 0.6595259308815002
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6457537412643433 - DICE: 0.7847078442573547
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9114384353160858
# Mean DICE: 0.9461769610643387
# Keras-IOU: 0.7645188570022583
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6485692858695984 - DICE: 0.786644697189331
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9121423214673996
# Mean DICE: 0.9466611742973328
# Keras-IOU: 0.49922120571136475
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00027144409250468016 - DICE: 0.00027144409250468016
# Falla tipo: 4 - IOU: 0.0008495574002154171 - DICE: 0.0008495574002154171
# Mean IOU: 0.50028025037318
# Mean DICE: 0.50028025037318
# Keras-IOU: 0.4956921339035034
#
# Falla tipo: 1 - IOU: 0.0030075188260525465 - DICE: 0.0030075188260525465
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7507518797065131
# Mean DICE: 0.7507518797065131
# Keras-IOU: 0.49962401390075684
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5791413187980652 - DICE: 0.7334614992141724
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8947853296995163
# Mean DICE: 0.9333653748035431
# Keras-IOU: 0.7332978248596191
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.003021148033440113 - DICE: 0.003021148033440113
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.75075528700836
# Mean DICE: 0.75075528700836
# Keras-IOU: 0.49961549043655396
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.11642378568649292 - DICE: 0.20855435729026794
# Falla tipo: 4 - IOU: 6.877008854644373e-05 - DICE: 6.877008854644373e-05
# Mean IOU: 0.5291231389437598
# Mean DICE: 0.5521557818447036
# Keras-IOU: 0.4196271598339081
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0009426134056411684 - DICE: 0.0014469549059867859
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7502356533514103
# Mean DICE: 0.7503617387264967
# Keras-IOU: 0.4974438548088074
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.3828362226486206 - DICE: 0.5536784529685974
# Mean IOU: 0.8457090556621552
# Mean DICE: 0.8884196132421494
# Keras-IOU: 0.7860623002052307
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5386844277381897 - DICE: 0.7001827955245972
# Falla tipo: 4 - IOU: 0.000526278221514076 - DICE: 0.000526278221514076
# Mean IOU: 0.6348026764899259
# Mean DICE: 0.6751772684365278
# Keras-IOU: 0.5297217965126038
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5558032989501953 - DICE: 0.7143272757530212
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8889508247375488
# Mean DICE: 0.9285818189382553
# Keras-IOU: 0.6364966630935669
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0724153071641922 - DICE: 0.13481338322162628
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.768103826791048
# Mean DICE: 0.7837033458054066
# Keras-IOU: 0.49603271484375
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5223380923271179 - DICE: 0.6861379742622375
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8805845230817795
# Mean DICE: 0.9215344935655594
# Keras-IOU: 0.7429629564285278
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 9.705517732072622e-05 - DICE: 9.705517732072622e-05
# Mean IOU: 0.7500242637943302
# Mean DICE: 0.7500242637943302
# Keras-IOU: 0.48781004548072815
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00044316420098766685 - DICE: 0.00044316420098766685
# Falla tipo: 4 - IOU: 0.0005239978199824691 - DICE: 0.0005239978199824691
# Mean IOU: 0.5002417905052425
# Mean DICE: 0.5002417905052425
# Keras-IOU: 0.4967297315597534
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.774869441986084 - DICE: 0.8731498718261719
# Falla tipo: 4 - IOU: 0.0020038101356476545 - DICE: 0.0020038101356476545
# Mean IOU: 0.6942183130304329
# Mean DICE: 0.7187884204904549
# Keras-IOU: 0.8523905277252197
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 0.00128369708545506 - DICE: 0.00128369708545506
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503209242713638
# Mean DICE: 0.7503209242713638
# Keras-IOU: 0.4991162121295929
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.052365854382514954 - DICE: 0.09933729469776154
# Falla tipo: 4 - IOU: 0.003580959513783455 - DICE: 0.003580959513783455
# Mean IOU: 0.5139867034740746
# Mean DICE: 0.5257295635528862
# Keras-IOU: 0.4946557581424713
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7767667174339294 - DICE: 0.8743171095848083
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9441916793584824
# Mean DICE: 0.9685792773962021
# Keras-IOU: 0.8540360927581787
#
# Falla tipo: 1 - IOU: 0.0013750429498031735 - DICE: 0.0013750429498031735
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503437607374508
# Mean DICE: 0.7503437607374508
# Keras-IOU: 0.49916258454322815
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0006078103906475008 - DICE: 0.0006078103906475008
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7501519525976619
# Mean DICE: 0.7501519525976619
# Keras-IOU: 0.4980786144733429
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6531438231468201 - DICE: 0.7901656627655029
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.913285955786705
# Mean DICE: 0.9475414156913757
# Keras-IOU: 0.7754653692245483
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.19747668504714966 - DICE: 0.329721063375473
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7993691712617874
# Mean DICE: 0.8324302658438683
# Keras-IOU: 0.5871754884719849
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.2520201802253723 - DICE: 0.40235188603401184
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8130050450563431
# Mean DICE: 0.850587971508503
# Keras-IOU: 0.49760133028030396
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0014986885944381356 - DICE: 0.0014986885944381356
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503746721486095
# Mean DICE: 0.7503746721486095
# Keras-IOU: 0.499267578125
#
# Falla tipo: 1 - IOU: 0.0007914523012004793 - DICE: 0.0007914523012004793
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.05315418541431427 - DICE: 0.05315418541431427
# Mean IOU: 0.5134864094288787
# Mean DICE: 0.5134864094288787
# Keras-IOU: 0.4985693395137787
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.3654056787490845 - DICE: 0.5351137518882751
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8413514196872711
# Mean DICE: 0.8837784379720688
# Keras-IOU: 0.665844738483429
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0012841091956943274 - DICE: 0.0012841091956943274
# Falla tipo: 4 - IOU: 0.049550946801900864 - DICE: 0.049550946801900864
# Mean IOU: 0.5127087639993988
# Mean DICE: 0.5127087639993988
# Keras-IOU: 0.4991491734981537
#
# Falla tipo: 1 - IOU: 0.0006058770231902599 - DICE: 0.0006058770231902599
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7501514692557976
# Mean DICE: 0.7501514692557976
# Keras-IOU: 0.49812376499176025
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.27571773529052734 - DICE: 0.43217313289642334
# Falla tipo: 4 - IOU: 0.000829000782687217 - DICE: 0.000829000782687217
# Mean IOU: 0.5691366840183036
# Mean DICE: 0.6082505334197776
# Keras-IOU: 0.5895196795463562
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.4931171238422394 - DICE: 0.6604881286621094
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8732792809605598
# Mean DICE: 0.9151220321655273
# Keras-IOU: 0.6636178493499756
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.4047429859638214 - DICE: 0.5761984586715698
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8511857464909554
# Mean DICE: 0.8940496146678925
# Keras-IOU: 0.6159423589706421
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00011697065929183736 - DICE: 0.00011697065929183736
# Falla tipo: 4 - IOU: 0.00022976190666668117 - DICE: 0.00022976190666668117
# Mean IOU: 0.5000866831414896
# Mean DICE: 0.5000866831414896
# Keras-IOU: 0.49619629979133606
#
# Falla tipo: 1 - IOU: 0.0007080899085849524 - DICE: 0.0007080899085849524
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7501770224771462
# Mean DICE: 0.7501770224771462
# Keras-IOU: 0.49842408299446106
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.5902514457702637 - DICE: 0.7423110604286194
# Mean IOU: 0.8975628614425659
# Mean DICE: 0.9355777651071548
# Keras-IOU: 0.7826259136199951
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.9774497747421265 - DICE: 0.9885956048965454
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9943624436855316
# Mean DICE: 0.9971489012241364
# Keras-IOU: 0.9511125087738037
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6380712389945984 - DICE: 0.7789488434791565
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9095178097486496
# Mean DICE: 0.9447372108697891
# Keras-IOU: 0.7986448407173157
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5709165334701538 - DICE: 0.7268426418304443
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8927291333675385
# Mean DICE: 0.9317106604576111
# Keras-IOU: 0.5491663813591003
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5582693815231323 - DICE: 0.7164566516876221
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8895673453807831
# Mean DICE: 0.9291141629219055
# Keras-IOU: 0.5853248238563538
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0013093289453536272 - DICE: 0.0013093289453536272
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503273322363384
# Mean DICE: 0.7503273322363384
# Keras-IOU: 0.49912598729133606
#
# Falla tipo: 1 - IOU: 0.0009796718368306756 - DICE: 0.0009796718368306756
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7502449179592077
# Mean DICE: 0.7502449179592077
# Keras-IOU: 0.4988134801387787
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 0.0025510203558951616 - DICE: 0.0025510203558951616
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7506377550889738
# Mean DICE: 0.7506377550889738
# Keras-IOU: 0.49956297874450684
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6637856960296631 - DICE: 0.7978553771972656
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9159464240074158
# Mean DICE: 0.9494638442993164
# Keras-IOU: 0.83345627784729
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.3528483211994171 - DICE: 0.521592915058136
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8382120802998543
# Mean DICE: 0.880398228764534
# Keras-IOU: 0.5926198959350586
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00022138588246889412 - DICE: 0.00022138588246889412
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7500553464706172
# Mean DICE: 0.7500553464706172
# Keras-IOU: 0.4946276843547821
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0013054830487817526 - DICE: 0.0013054830487817526
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503263707621954
# Mean DICE: 0.7503263707621954
# Keras-IOU: 0.4991516172885895
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.001952095772139728 - DICE: 0.0037655499763786793
# Falla tipo: 4 - IOU: 0.00012551322288345546 - DICE: 0.00012551322288345546
# Mean IOU: 0.5005194022487558
# Mean DICE: 0.5009727657998155
# Keras-IOU: 0.48772215843200684
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.002406738931313157 - DICE: 0.002406738931313157
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7506016847328283
# Mean DICE: 0.7506016847328283
# Keras-IOU: 0.49957275390625
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.35097938776016235 - DICE: 0.5195532441139221
# Falla tipo: 4 - IOU: 0.0005949315964244306 - DICE: 0.0005949315964244306
# Mean IOU: 0.5878935798391467
# Mean DICE: 0.6300370439275866
# Keras-IOU: 0.5308964848518372
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5097351670265198 - DICE: 0.6752082705497742
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8774337917566299
# Mean DICE: 0.9188020676374435
# Keras-IOU: 0.5182768702507019
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 0.001207729452289641 - DICE: 0.001207729452289641
# Falla tipo: 2 - IOU: 0.001733102253638208 - DICE: 0.001733102253638208
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.500735207926482
# Mean DICE: 0.500735207926482
# Keras-IOU: 0.4984094202518463
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.002680965233594179 - DICE: 0.002680965233594179
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7506702413083985
# Mean DICE: 0.7506702413083985
# Keras-IOU: 0.499603271484375
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0006584362126886845 - DICE: 0.0006584362126886845
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7501646090531722
# Mean DICE: 0.7501646090531722
# Keras-IOU: 0.49827271699905396
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5701224207878113 - DICE: 0.7261891961097717
# Falla tipo: 4 - IOU: 0.09488880634307861 - DICE: 0.09488880634307861
# Mean IOU: 0.6662528067827225
# Mean DICE: 0.7052695006132126
# Keras-IOU: 0.6754425764083862
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.21386076509952545 - DICE: 0.3522716760635376
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8034651912748814
# Mean DICE: 0.8380679190158844
# Keras-IOU: 0.5921191573143005
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.6253892183303833 - DICE: 0.7694777846336365
# Mean IOU: 0.9063473045825958
# Mean DICE: 0.9423694461584091
# Keras-IOU: 0.8520961999893188
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5826197862625122 - DICE: 0.7362692356109619
# Falla tipo: 4 - IOU: 0.00013730244245380163 - DICE: 0.00013730244245380163
# Mean IOU: 0.6456892721762415
# Mean DICE: 0.6841016345133539
# Keras-IOU: 0.6007498502731323
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00048467222950421274 - DICE: 0.00048467222950421274
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.750121168057376
# Mean DICE: 0.750121168057376
# Keras-IOU: 0.4975634813308716
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 0.0012326656142249703 - DICE: 0.0012326656142249703
# Falla tipo: 3 - IOU: 0.0005027634906582534 - DICE: 0.0005027634906582534
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.5004338572762208
# Mean DICE: 0.5004338572762208
# Keras-IOU: 0.4978979527950287
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7834396362304688 - DICE: 0.8785535097122192
# Falla tipo: 4 - IOU: 0.0006904552574269474 - DICE: 0.0006904552574269474
# Mean IOU: 0.6960325228719739
# Mean DICE: 0.7198109912424115
# Keras-IOU: 0.8449413180351257
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00011325028026476502 - DICE: 0.00011325028026476502
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7500283125700662
# Mean DICE: 0.7500283125700662
# Keras-IOU: 0.48994141817092896
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0022833850234746933 - DICE: 0.004028291907161474
# Falla tipo: 4 - IOU: 0.8573154807090759 - DICE: 0.9231754541397095
# Mean IOU: 0.7148997164331377
# Mean DICE: 0.7318009365117177
# Keras-IOU: 0.8181651830673218
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.4420529901981354 - DICE: 0.6127411723136902
# Falla tipo: 4 - IOU: 0.012095062993466854 - DICE: 0.012095062993466854
# Mean IOU: 0.6135370132979006
# Mean DICE: 0.6562090588267893
# Keras-IOU: 0.49921754002571106
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.09355130046606064 - DICE: 0.17076733708381653
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7733878251165152
# Mean DICE: 0.7926918342709541
# Keras-IOU: 0.49730467796325684
#
# Falla tipo: 1 - IOU: 0.000521104724612087 - DICE: 0.000521104724612087
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.750130276181153
# Mean DICE: 0.750130276181153
# Keras-IOU: 0.49781858921051025
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.00031173715251497924 - DICE: 0.00031173715251497924
# Mean IOU: 0.7500779342881287
# Mean DICE: 0.7500779342881287
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6969506144523621 - DICE: 0.8214014768600464
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9242376536130905
# Mean DICE: 0.9553503692150116
# Keras-IOU: 0.8530449867248535
#
# Falla tipo: 1 - IOU: 0.00421496294438839 - DICE: 0.00421496294438839
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7510537407360971
# Mean DICE: 0.7510537407360971
# Keras-IOU: 0.49973511695861816
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6827977895736694 - DICE: 0.8114416599273682
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9206994473934174
# Mean DICE: 0.952860414981842
# Keras-IOU: 0.8453030586242676
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0015734253684058785 - DICE: 0.0015734253684058785
# Falla tipo: 4 - IOU: 0.00024552602553740144 - DICE: 0.00024552602553740144
# Mean IOU: 0.5004547378484858
# Mean DICE: 0.5004547378484858
# Keras-IOU: 0.49711549282073975
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.3441410958766937 - DICE: 0.5119816660881042
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8360352739691734
# Mean DICE: 0.8779954165220261
# Keras-IOU: 0.5592576861381531
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7035595178604126 - DICE: 0.825973629951477
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9258898794651031
# Mean DICE: 0.9564934074878693
# Keras-IOU: 0.7860490083694458
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7074465155601501 - DICE: 0.828629195690155
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9268616288900375
# Mean DICE: 0.9571572989225388
# Keras-IOU: 0.8017094135284424
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0016032063867896795 - DICE: 0.0016032063867896795
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7504008015966974
# Mean DICE: 0.7504008015966974
# Keras-IOU: 0.4993579089641571
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5266857147216797 - DICE: 0.6899493336677551
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8816714286804199
# Mean DICE: 0.9224873334169388
# Keras-IOU: 0.6292609572410583
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0019714145455509424 - DICE: 0.0019714145455509424
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7504928536363877
# Mean DICE: 0.7504928536363877
# Keras-IOU: 0.49943602085113525
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.4561145305633545 - DICE: 0.6264700293540955
# Falla tipo: 4 - IOU: 0.00024329818552359939 - DICE: 0.00024329818552359939
# Mean IOU: 0.6140894571872195
# Mean DICE: 0.6566783318849048
# Keras-IOU: 0.6370381116867065
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.1197894737124443 - DICE: 0.21314577758312225
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7799473684281111
# Mean DICE: 0.8032864443957806
# Keras-IOU: 0.49901244044303894
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.6001453399658203 - DICE: 0.7500771284103394
# Mean IOU: 0.9000363349914551
# Mean DICE: 0.9375192821025848
# Keras-IOU: 0.8336272239685059
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6111150979995728 - DICE: 0.758614718914032
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9027787744998932
# Mean DICE: 0.939653679728508
# Keras-IOU: 0.72184157371521
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0004930009599775076 - DICE: 0.0004930009599775076
# Falla tipo: 4 - IOU: 0.02769588865339756 - DICE: 0.02769588865339756
# Mean IOU: 0.5070472224033438
# Mean DICE: 0.5070472224033438
# Keras-IOU: 0.49784302711486816
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.3889573812484741 - DICE: 0.5596354007720947
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8472393453121185
# Mean DICE: 0.8899088501930237
# Keras-IOU: 0.49915894865989685
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0008892841287888587 - DICE: 0.0008892841287888587
# Falla tipo: 4 - IOU: 0.0005019851378165185 - DICE: 0.0005019851378165185
# Mean IOU: 0.5003478173166513
# Mean DICE: 0.5003478173166513
# Keras-IOU: 0.4973767101764679
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5003865361213684 - DICE: 0.6669659614562988
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8750966340303421
# Mean DICE: 0.9167414903640747
# Keras-IOU: 0.6546424627304077
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.11582218110561371 - DICE: 0.20745401084423065
# Falla tipo: 4 - IOU: 0.0001805277424864471 - DICE: 0.0001805277424864471
# Mean IOU: 0.529000677212025
# Mean DICE: 0.5519086346466793
# Keras-IOU: 0.5009829998016357
#
# Falla tipo: 1 - IOU: 0.0017738359747454524 - DICE: 0.0017738359747454524
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7504434589936864
# Mean DICE: 0.7504434589936864
# Keras-IOU: 0.4993652403354645
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0003779646649491042 - DICE: 0.0003779646649491042
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7500944911662373
# Mean DICE: 0.7500944911662373
# Keras-IOU: 0.49690550565719604
#
# Falla tipo: 1 - IOU: 0.003189792623743415 - DICE: 0.003189792623743415
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7507974481559359
# Mean DICE: 0.7507974481559359
# Keras-IOU: 0.49965208768844604
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.45137283205986023 - DICE: 0.6217824816703796
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8628432080149651
# Mean DICE: 0.9054456204175949
# Keras-IOU: 0.6762561202049255
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0003843197482638061 - DICE: 0.0003843197482638061
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.750096079937066
# Mean DICE: 0.750096079937066
# Keras-IOU: 0.4970129430294037
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0015680125216022134 - DICE: 0.0015680125216022134
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503920031304006
# Mean DICE: 0.7503920031304006
# Keras-IOU: 0.49931883811950684
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.4063340723514557 - DICE: 0.5778387784957886
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8515835180878639
# Mean DICE: 0.8944596946239471
# Keras-IOU: 0.5953308939933777
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0031471282709389925 - DICE: 0.0031471282709389925
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7507867820677347
# Mean DICE: 0.7507867820677347
# Keras-IOU: 0.4996374547481537
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.005578800570219755 - DICE: 0.005578800570219755
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7513947001425549
# Mean DICE: 0.7513947001425549
# Keras-IOU: 0.49982789158821106
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5638827681541443 - DICE: 0.7210142612457275
# Falla tipo: 4 - IOU: 0.015914693474769592 - DICE: 0.015914693474769592
# Mean IOU: 0.6449493654072285
# Mean DICE: 0.6842322386801243
# Keras-IOU: 0.7412905693054199
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.5875428915023804 - DICE: 0.7401759028434753
# Mean IOU: 0.8968857228755951
# Mean DICE: 0.9350439757108688
# Keras-IOU: 0.757396936416626
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.8313054442405701 - DICE: 0.9078768491744995
# Mean IOU: 0.9578263610601425
# Mean DICE: 0.9769692122936249
# Keras-IOU: 0.8500491380691528
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# ...
# Mean DICE: 0.750057514233049
# Keras-IOU: 0.49485352635383606
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.21621818840503693 - DICE: 0.3554852306842804
# Falla tipo: 4 - IOU: 0.0003418532432988286 - DICE: 0.0003418532432988286
# Mean IOU: 0.5541400104120839
# Mean DICE: 0.5889567709818948
# Keras-IOU: 0.49118316173553467
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.23749572038650513 - DICE: 0.38345077633857727
# Falla tipo: 4 - IOU: 0.0023992108181118965 - DICE: 0.0023992108181118965
# Mean IOU: 0.5599737328011543
# Mean DICE: 0.5964624967891723
# Keras-IOU: 0.5323114395141602
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.28982749581336975 - DICE: 0.449248343706131
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8224568739533424
# Mean DICE: 0.8623120859265327
# Keras-IOU: 0.5851755738258362
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 7.457121682818979e-05 - DICE: 7.457121682818979e-05
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.750018642804207
# Mean DICE: 0.750018642804207
# Keras-IOU: 0.4839733839035034
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.41210320591926575 - DICE: 0.5836277008056641
# Falla tipo: 4 - IOU: 0.8504467606544495 - DICE: 0.919167697429657
# Mean IOU: 0.8156374916434288
# Mean DICE: 0.8756988495588303
# Keras-IOU: 0.7215456366539001
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7025262713432312 - DICE: 0.8252586126327515
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9256315678358078
# Mean DICE: 0.9563146531581879
# Keras-IOU: 0.8145384788513184
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 8.153281669365242e-05 - DICE: 8.153281669365242e-05
# Falla tipo: 4 - IOU: 0.002982632489874959 - DICE: 0.002982632489874959
# Mean IOU: 0.5007660413266422
# Mean DICE: 0.5007660413266422
# Keras-IOU: 0.4852368235588074
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.43137308955192566 - DICE: 0.6026380658149719
# Mean IOU: 0.8578432723879814
# Mean DICE: 0.900659516453743
# Keras-IOU: 0.4967980980873108
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.04308408498764038 - DICE: 0.08250855654478073
# Falla tipo: 4 - IOU: 0.00026057311333715916 - DICE: 0.00026057311333715916
# Mean IOU: 0.5108361645252444
# Mean DICE: 0.5206922824145295
# Keras-IOU: 0.4894702136516571
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7100672721862793 - DICE: 0.8303850889205933
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9275168180465698
# Mean DICE: 0.9575962722301483
# Keras-IOU: 0.8099865913391113
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0016799663426354527 - DICE: 0.0016799663426354527
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7504199915856589
# Mean DICE: 0.7504199915856589
# Keras-IOU: 0.49931153655052185
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0004651703638955951 - DICE: 0.0004651703638955951
# Falla tipo: 4 - IOU: 0.0021156168077141047 - DICE: 0.0021156168077141047
# Mean IOU: 0.5006451967929024
# Mean DICE: 0.5006451967929024
# Keras-IOU: 0.49745482206344604
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00016558347851969302 - DICE: 0.00016558347851969302
# Falla tipo: 4 - IOU: 0.0005001731333322823 - DICE: 0.0005001731333322823
# Mean IOU: 0.500166439152963
# Mean DICE: 0.500166439152963
# Keras-IOU: 0.4927990734577179
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.2743930518627167 - DICE: 0.4304982125759125
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8185982629656792
# Mean DICE: 0.8576245531439781
# Keras-IOU: 0.5935633182525635
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.030889272689819336 - DICE: 0.030889272689819336
# Falla tipo: 4 - IOU: 0.8455821871757507 - DICE: 0.9163194298744202
# Mean IOU: 0.7191178649663925
# Mean DICE: 0.7368021756410599
# Keras-IOU: 0.8951377868652344
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.16153523325920105 - DICE: 0.27796974778175354
# Falla tipo: 4 - IOU: 0.002882710425183177 - DICE: 0.002882710425183177
# Mean IOU: 0.5411044859210961
# Mean DICE: 0.5702131145517342
# Keras-IOU: 0.49601197242736816
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6223198771476746 - DICE: 0.7671757340431213
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9055799692869186
# Mean DICE: 0.9417939335107803
# Keras-IOU: 0.7374608516693115
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.44879016280174255 - DICE: 0.6195347309112549
# Falla tipo: 4 - IOU: 0.003584005171433091 - DICE: 0.003584005171433091
# Mean IOU: 0.6130935419932939
# Mean DICE: 0.655779684020672
# Keras-IOU: 0.5686907768249512
#
# Falla tipo: 1 - IOU: 0.0032310178503394127 - DICE: 0.0032310178503394127
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7508077544625849
# Mean DICE: 0.7508077544625849
# Keras-IOU: 0.49965086579322815
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.46805715560913086 - DICE: 0.6376471519470215
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8670142889022827
# Mean DICE: 0.9094117879867554
# Keras-IOU: 0.6030045747756958
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00018330125021748245 - DICE: 0.00018330125021748245
# Falla tipo: 4 - IOU: 0.6445714831352234 - DICE: 0.7838646173477173
# Mean IOU: 0.6611886960963602
# Mean DICE: 0.6960119796494837
# Keras-IOU: 0.6383687853813171
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.7610429525375366 - DICE: 0.8642920255661011
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9402607381343842
# Mean DICE: 0.9660730063915253
# Keras-IOU: 0.7760523557662964
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6877990961074829 - DICE: 0.8149845600128174
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9219497740268707
# Mean DICE: 0.9537461400032043
# Keras-IOU: 0.7770023345947266
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0015929908258840442 - DICE: 0.0015929908258840442
# Falla tipo: 4 - IOU: 0.008156458847224712 - DICE: 0.008156458847224712
# Mean IOU: 0.5024373624182772
# Mean DICE: 0.5024373624182772
# Keras-IOU: 0.49927735328674316
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6152332425117493 - DICE: 0.7617817521095276
# Falla tipo: 4 - IOU: 0.0010788114741444588 - DICE: 0.0010788114741444588
# Mean IOU: 0.6540780134964734
# Mean DICE: 0.690715140895918
# Keras-IOU: 0.7562384605407715
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.48156359791755676 - DICE: 0.6499767899513245
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8703908994793892
# Mean DICE: 0.9124941974878311
# Keras-IOU: 0.5295768976211548
#
# Falla tipo: 1 - IOU: 0.0025348542258143425 - DICE: 0.0025348542258143425
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7506337135564536
# Mean DICE: 0.7506337135564536
# Keras-IOU: 0.49955323338508606
#
# Falla tipo: 1 - IOU: 0.001853568130172789 - DICE: 0.001853568130172789
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7504633920325432
# Mean DICE: 0.7504633920325432
# Keras-IOU: 0.49940916895866394
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.7175579071044922 - DICE: 0.8355408310890198
# Mean IOU: 0.929389476776123
# Mean DICE: 0.9588852077722549
# Keras-IOU: 0.8331724405288696
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.37683555483818054 - DICE: 0.5473095774650574
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8442088887095451
# Mean DICE: 0.8868273943662643
# Keras-IOU: 0.6549901962280273
#
# Falla tipo: 1 - IOU: 0.002475247485563159 - DICE: 0.002475247485563159
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7506188118713908
# Mean DICE: 0.7506188118713908
# Keras-IOU: 0.4995397925376892
#
# Falla tipo: 1 - IOU: 0.0020597323309630156 - DICE: 0.0020597323309630156
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7505149330827408
# Mean DICE: 0.7505149330827408
# Keras-IOU: 0.4994433522224426
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6829485893249512 - DICE: 0.8116023540496826
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9207371473312378
# Mean DICE: 0.9529005885124207
# Keras-IOU: 0.7414627075195312
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.6802533864974976 - DICE: 0.8096832633018494
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.9200633466243744
# Mean DICE: 0.9524208158254623
# Keras-IOU: 0.7823327779769897
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 0.0009535161079838872 - DICE: 0.0009535161079838872
# Falla tipo: 3 - IOU: 0.001812415081076324 - DICE: 0.001812415081076324
# Falla tipo: 4 - IOU: 0.4180253744125366 - DICE: 0.4180253744125366
# Mean IOU: 0.3551978264003992
# Mean DICE: 0.3551978264003992
# Keras-IOU: 0.4981689453125
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.15995295345783234 - DICE: 0.2749839425086975
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7899882383644581
# Mean DICE: 0.8187459856271744
# Keras-IOU: 0.4992114305496216
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.4638198912143707 - DICE: 0.6336498856544495
# Falla tipo: 4 - IOU: 0.005476305726915598 - DICE: 0.005476305726915598
# Mean IOU: 0.6173240492353216
# Mean DICE: 0.6597815478453413
# Keras-IOU: 0.4951464831829071
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00024654832668602467 - DICE: 0.00024654832668602467
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7500616370816715
# Mean DICE: 0.7500616370816715
# Keras-IOU: 0.4952062964439392
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0014440433587878942 - DICE: 0.0014440433587878942
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.750361010839697
# Mean DICE: 0.750361010839697
# Keras-IOU: 0.49922850728034973
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0007263483130373061 - DICE: 0.0007263483130373061
# Falla tipo: 4 - IOU: 0.0013722925214096904 - DICE: 0.0013722925214096904
# Mean IOU: 0.5005246602086117
# Mean DICE: 0.5005246602086117
# Keras-IOU: 0.4984130859375
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5016546845436096 - DICE: 0.6679983139038086
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8754136711359024
# Mean DICE: 0.9169995784759521
# Keras-IOU: 0.7402795553207397
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.000971345289144665 - DICE: 0.000971345289144665
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7502428363222862
# Mean DICE: 0.7502428363222862
# Keras-IOU: 0.49888792634010315
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 0.0013788348296657205 - DICE: 0.0013788348296657205
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.7503447087074164
# Mean DICE: 0.7503447087074164
# Keras-IOU: 0.4991723597049713
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.5530380606651306 - DICE: 0.7121596932411194
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8882595151662827
# Mean DICE: 0.9280399233102798
# Keras-IOU: 0.5886601805686951
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.2572701573371887 - DICE: 0.4090653359889984
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8143175393342972
# Mean DICE: 0.8522663339972496
# Keras-IOU: 0.6613477468490601
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.31681087613105774 - DICE: 0.4808686375617981
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.8292027190327644
# Mean DICE: 0.8702171593904495
# Keras-IOU: 0.5560039281845093
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0008369883289560676 - DICE: 0.0008369883289560676
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.750209247082239
# Mean DICE: 0.750209247082239
# Keras-IOU: 0.49867308139801025
#
# Falla tipo: 1 - IOU: 0.00029455081676132977 - DICE: 0.00029455081676132977
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.0001580902753630653 - DICE: 0.0001580902753630653
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 0.5001131602730311
# Mean DICE: 0.5001131602730311
# Keras-IOU: 0.4884912073612213
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 0.0002240046887891367 - DICE: 0.0002240046887891367
# Mean IOU: 0.7500560011721973
# Mean DICE: 0.7500560011721973
# Keras-IOU: 1.0
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.00040120360790751874 - DICE: 0.00040120360790751874
# Falla tipo: 4 - IOU: 0.7408847212791443 - DICE: 0.8511554598808289
# Mean IOU: 0.685321481221763
# Mean DICE: 0.7128891658721841
# Keras-IOU: 0.7623772621154785
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 0.023143265396356583 - DICE: 0.0451652817428112
# Falla tipo: 4 - IOU: 0.7379682064056396 - DICE: 0.8492212295532227
# Mean IOU: 0.6902778679504991
# Mean DICE: 0.7235966278240085
# Keras-IOU: 0.5793828964233398
#
# Falla tipo: 1 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 2 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 3 - IOU: 1.0 - DICE: 1.0
# Falla tipo: 4 - IOU: 1.0 - DICE: 1.0
# Mean IOU: 1.0
# Mean DICE: 1.0
# Keras-IOU: 1.0
#
# Mean IOU Total: 0.7820454426274615
# Mean DICE Total: 0.6474697020625548
# Keras-IOU Total: 0.8012750002980523

# %%
union
# Out:
# array([[  87567,   20306, 3404588, 1087318]])

# %%
pixel_accuracy
# Out:
# 0.9882718436009877

# %%
mean_iou
# Out:
# array([[0.        , 0.        , 0.34953378, 0.46867476]])

# %%
dice
# Out:
# array([[0.       , 0.       , 0.5258644, 0.6422713]], dtype=float32)

# %%
print(dice2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-1b5305285b64> in <module>
# ----> 1 print(dice2)
#
# NameError: name 'dice2' is not defined

# %%
for i in range(10):
    data_test = next(test_generator)
    y_true = data_test[1]
    print(dice_loss(y_true,model2.predict(data_test[0])))
# Out:
# tf.Tensor(0.017955303, shape=(), dtype=float32)
# tf.Tensor(0.7205803, shape=(), dtype=float32)
# tf.Tensor(0.25446177, shape=(), dtype=float32)
# tf.Tensor(0.018603206, shape=(), dtype=float32)
# tf.Tensor(0.99992746, shape=(), dtype=float32)
# tf.Tensor(0.9985142, shape=(), dtype=float32)
# tf.Tensor(0.22992927, shape=(), dtype=float32)
# tf.Tensor(0.9109885, shape=(), dtype=float32)
# tf.Tensor(0.9996821, shape=(), dtype=float32)
# tf.Tensor(0.018184185, shape=(), dtype=float32)
